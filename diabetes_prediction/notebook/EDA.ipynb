# %%
import pandas as pd
import sys
from pathlib import Path
root_path = Path().resolve().parent.parent

sys.path.append(str(root_path))
from utils.eda import *
from utils.visualization import *

# %%
df = pd.read_csv(root_path / "diabetes_prediction" / 'data' / 'diabetes.csv')
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
summary_stats(df)
# Out:
# ============================================================
# SHAPE        : 768 rows × 9 columns
# ============================================================
#
# ── DTYPES ──
#                             dtype  nunique   sample
# Pregnancies                 int64       17    6.000
# Glucose                     int64      136  148.000
# BloodPressure               int64       47   72.000
# SkinThickness               int64       51   35.000
# Insulin                     int64      186    0.000
# BMI                       float64      248   33.600
# DiabetesPedigreeFunction  float64      517    0.627
# Age                         int64       52   50.000
# Outcome                     int64        2    1.000

# %%
missing_report(df)
# Out:
# ==================================================
# MISSING VALUE REPORT  (total kolom: 9)
# ==================================================
# ✓ Tidak ada missing values.

# %%
df.duplicated().sum()
# Out:
# 0

# %%
plot_distributions(df, df.columns.tolist())

# %%
outlier_report(df)
# Out:
# =======================================================
# OUTLIER REPORT  (method=iqr)
# =======================================================
#                   column  n_outliers  pct_outliers  has_outlier  lower_bound  upper_bound
#            BloodPressure          45          5.86         True       35.000      107.000
#                  Insulin          34          4.43         True     -190.875      318.125
# DiabetesPedigreeFunction          29          3.78         True       -0.330        1.200
#                      BMI          19          2.47         True       13.350       50.550
#                      Age           9          1.17         True       -1.500       66.500
#                  Glucose           5          0.65         True       37.125      202.125
#              Pregnancies           4          0.52         True       -6.500       13.500
#            SkinThickness           1          0.13         True      -48.000       80.000
#
# Kolom dengan outlier: 8 / 9

# %%
plot_boxplot(df, df.columns.tolist())

# %%
class_balance(df, 'Outcome')
# Out:
# ========================================
# CLASS BALANCE — 'Outcome'
# ========================================
#          count   pct
# Outcome
# 0          500  65.1
# 1          268  34.9
#
# Imbalance ratio (max/min): 1.87x
# ✓  Dataset relatif balanced.

# %%
plot_class_balance(df, 'Outcome')

# %%
correlation_matrix(df)
