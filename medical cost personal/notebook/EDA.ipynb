# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import sys
from pathlib import Path
root_path = Path().resolve().parent.parent
sys.path.append(str(root_path))

from utils.eda import summary_stats, missing_report, outlier_report, correlation_matrix
from utils.visualization import *

# %%
df = pd.read_csv(root_path / "medical cost personal" / 'data' / 'insurance.csv')
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
summary_stats(df)
# Out:
# ============================================================
# SHAPE        : 1338 rows × 7 columns
# ============================================================
#
# ── DTYPES ──
#             dtype  nunique     sample
# age         int64       47         19
# sex        object        2     female
# bmi       float64      548       27.9
# children    int64        6          0
# smoker     object        2        yes
# region     object        4  southwest
# charges   float64     1337  16884.924

# %%
missing_report(df)
# Out:
# ==================================================
# MISSING VALUE REPORT  (total kolom: 7)
# ==================================================
# ✓ Tidak ada missing values.

# %%
df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
outlier_report(df)
# Out:
# =======================================================
# OUTLIER REPORT  (method=iqr)
# =======================================================
#  column  n_outliers  pct_outliers  has_outlier  lower_bound  upper_bound
# charges         139         10.39         True  -13109.1509   34489.3506
#     bmi           9          0.67         True      13.7000      47.2900
#
# Kolom dengan outlier: 2 / 4

# %%
print(f"Jumlah data duplikat: {df.duplicated().sum()}")
# Out:
# Jumlah data duplikat: 1

# %%
fitur_numeric = df.select_dtypes(include='number').columns.tolist()
fitur_category = df.select_dtypes(include='object').columns.tolist()

# %%
plot_distributions(df, fitur_numeric)

# %%
plot_distributions(df, fitur_category)

# %%
plot_boxplot(df, fitur_numeric)

# %%
correlation_matrix(df)
