# %%
import numpy as pd
import pandas as pd
import sys
from pathlib import Path
root_path = Path().resolve().parent

sys.path.append(str(root_path))
from utils.eda import *
from utils.visualization import *

# %%
df = pd.read_csv("data/winequality-red.csv")
df.head()
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
summary_stats(df)
# Out:
# ...
# SHAPE        : 1599 rows × 12 columns
# ...
#
# ── DTYPES ──
#                         dtype  nunique   sample
# fixed_acidity         float64       96   7.4000
# volatile_acidity      float64      143   0.7000
# citric_acid           float64       80   0.0000
# residual_sugar        float64       91   1.9000
# chlorides             float64      153   0.0760
# free_sulfur_dioxide   float64       60  11.0000
# total_sulfur_dioxide  float64      144  34.0000
# density               float64      436   0.9978
# pH                    float64       89   3.5100
# sulphates             float64       96   0.5600
# alcohol               float64       65   9.4000
# quality                 int64        6   5.0000

# %%
class_balance(df, 'quality')
# Out:
# ...
# CLASS BALANCE — 'quality'
# ...
#          count    pct
# quality
# 5          681  42.59
# 6          638  39.90
# 7          199  12.45
# 4           53   3.31
# 8           18   1.13
# 3           10   0.63
#
# Imbalance ratio (max/min): 68.10x
# ⚠  Dataset tampak imbalanced (ratio > 3).

# %%
plot_class_balance(df, 'quality')

# %%
missing_report(df)
# Out:
# ...
# MISSING VALUE REPORT  (total kolom: 12)
# ...
# ✓ Tidak ada missing values.

# %%
plot_distributions(df)

# %%
plot_boxplot(df, df.columns.tolist())

# %%
outlier_report(df)
# Out:
# ...
# OUTLIER REPORT  (method=iqr)
# ...
#               column  n_outliers  pct_outliers  has_outlier  lower_bound  upper_bound
#       residual_sugar         155          9.69         True       0.8500       3.6500
#            chlorides         112          7.00         True       0.0400       0.1200
#            sulphates          59          3.69         True       0.2800       1.0000
# total_sulfur_dioxide          55          3.44         True     -38.0000     122.0000
#        fixed_acidity          49          3.06         True       3.9500      12.3500
#              density          45          2.81         True       0.9922       1.0012
#                   pH          35          2.19         True       2.9250       3.6850
#  free_sulfur_dioxide          30          1.88         True     -14.0000      42.0000
#              quality          28          1.75         True       3.5000       7.5000
#     volatile_acidity          19          1.19         True       0.0150       1.0150
# ...

# %%
correlation_matrix(df)

# %% [markdown]
# ## Profil Dataset
# - Ukuran dataset memiliki 1599 rows × 12 columns
# - Dataset untuk semua feature terdiri dari numerik `float64` sehingga kita tidak perlu lagi encoding feature.
# - Data target mengalami imbalance data.
#
# | quality | count | pct |
# | :---: | :---: | :---: |
# | 5 | 681 | 42.59 |
# | 6 | 638 | 39.90 |
# | 7 | 199 | 12.45 |
# | 4 | 53 | 3.31 |
# | 8 | 18 | 1.13 |
# | 3 | 10 | 0.63 |
#
# ## Missing Report
# - Tidak ada row atau value yang kosong
#
# ## Outlier Report
# - Semua kolom mempunyai outlier, tapi semuanya masih di bawah 10% sehingga bisa di capping
