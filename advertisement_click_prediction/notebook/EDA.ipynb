# %%
import pandas as pd
import sys
from pathlib import Path
root_path = Path().resolve().parent.parent

sys.path.append(str(root_path))
from utils.eda import *
from utils.visualization import *

# %%
df = pd.read_csv("../data/Social_Network_Ads.csv")
df.head()
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510    Male   19            19000          0
# 1  15810944    Male   35            20000          0
# 2  15668575  Female   26            43000          0
# 3  15603246  Female   27            57000          0
# 4  15804002    Male   19            76000          0

# %%
summary_stats(df)
# Out:
# ...
# SHAPE        : 400 rows × 5 columns
# ...
#
# ── DTYPES ──
#                   dtype  nunique    sample
# User ID           int64      400  15624510
# Gender           object        2      Male
# Age               int64       43        19
# EstimatedSalary   int64      117     19000
# Purchased         int64        2         0

# %%
missing_report(df)
# Out:
# ...
# MISSING VALUE REPORT  (total kolom: 5)
# ...
# ✓ Tidak ada missing values.

# %%
print(f"Jumlah duplikat: {df.duplicated().sum()}")
# Out:
# Jumlah duplikat: 0

# %%
## distribusi
fitur_numeric = df.select_dtypes(include='number').columns.tolist()
fitur_categorical = df.select_dtypes(include=object).columns.tolist()

# %%
plot_distributions(df, fitur_numeric)

# %%
plot_distributions(df, fitur_categorical)

# %%
outlier_report(df)
# Out:
# ...
# OUTLIER REPORT  (method=iqr)
# ...
# Empty DataFrame
# Columns: [column, n_outliers, pct_outliers, has_outlier, lower_bound, upper_bound]
# Index: []
#
# Kolom dengan outlier: 0 / 4

# %%
plot_boxplot(df, fitur_numeric)

# %%
class_balance(df, 'Purchased')
# Out:
# ...
# CLASS BALANCE — 'Purchased'
# ...
#            count    pct
# Purchased
# 0            257  64.25
# 1            143  35.75
#
# Imbalance ratio (max/min): 1.80x
# ✓  Dataset relatif balanced.

# %%
plot_class_balance(df, 'Purchased')

# %%
correlation_matrix(df)

# %% [markdown]
# ## Profil dataset
# - Ukuran dataset memiliki 400 rows × 5 columns
# - Data Target tidak mengalami imbalance data.
# - Dataset terdiri dari fitur numerik `int64` dan fitur kategori `object`.
# - Tidak ada missing value, outlier sehingga tidak perlu imputasi
# - Gender perlu di encoding untuk male dan female saja
